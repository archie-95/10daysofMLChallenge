# %%
#I have completed this code by taking the reference from the Kaggle Notebook
#https://www.kaggleusercontent.com/kf/30877167/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..j2NOOylqthmr0bdOGIC3QA.tBkNXI00V0we6mIpTHwtF6V8xXjjjS3hEgYv8LWJ07N_fq-lOVSZjmCSqBOkkd2AhA-tEqtG9woHa7UgT3Q99whH2Z1HQKCGehUyeLJ-Te5s6e_E-lC81JM1hkl2krMJKbk11eFm6P7bnX01aylZwD8Z-T607Z6aYhyBTVWnZ62Ubs2Kk97c40vslKEW-y8CwkgtkJwrkFvzZ6f1YzVnc0H-iwtbFaQqRVIx0osyXkciSnHJaLHF-vd9YHwXyKBEvK5Z9drqB1qAc2KE0LfVZm4WOp8w7nMjWJ6onVSbTbl6ZMi-2VRTUM3fBy05oF4P4mlSNBvUyxnfXKb5_YluH8RquP7imqmkQfKyPBXb1oT4n2rirPFhuQ9ZQUp0t7f3z7EcXb2HqRBwpOkWlY7fb0EUr3yafNL574d9L05fQLLEW1EEQzIuuRXAkWWkj8k2CFRayJLf7NPRXUziYEK1hopoXOdEyKqBp47kYHxhZca1P8htraVAuj7pI7HYqVp874deBByKAAHaQ07guQPejTXmgNVnKfIPgNRSzQDP_b3jTde2QuuH61TxIsXSh_zh5lSo_eW3Olvh32Kja_d5feIsSy20UfGtbg760pjC1vJxVtrgdOZOFlk7aTJQMVw53-o1RVksgm7SkPmAPI0wa7vhqj0RjNc4crPR91ENEGrp8387thVgIOGPGAZh9iBVECdmUvH9OqSRR_nh7bYRFQ.mnZuwYqf-16VlO4TbhH6lg/rishitdagli.ml

# the Dataset can be accesed from : https://www.kaggle.com/c/expedia-personalized-sort/data

# %%
import numpy as np
import pandas as pd 
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
import sklearn

# %%
train = pd.read_csv('train.csv')

# %%
train.head(10)
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
# 5        1  2013-04-04 08:32:15       12                          187
# 6        1  2013-04-04 08:32:15       12                          187
# 7        1  2013-04-04 08:32:15       12                          187
# 8        1  2013-04-04 08:32:15       12                          187
# 9        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# ...

# %%
train.isnull()
# Out:
#          srch_id  date_time  site_id  visitor_location_country_id  \
# 0          False      False    False                        False
# 1          False      False    False                        False
# 2          False      False    False                        False
# 3          False      False    False                        False
# 4          False      False    False                        False
# ...          ...        ...      ...                          ...
# 9917525    False      False    False                        False
# 9917526    False      False    False                        False
# 9917527    False      False    False                        False
# 9917528    False      False    False                        False
# 9917529    False      False    False                        False
#
#          visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  \
# 0                           True                  True            False
# ...

# %%
df = train.loc[train['prop_id'] == 104517]

df = df.loc[df['visitor_location_country_id'] == 219]

df = df.loc[df['srch_room_count'] == 1]

df = df[['date_time', 'price_usd', 'srch_booking_window', 'srch_saturday_night_bool']]

# %%
df.describe()
# Out:
#          price_usd  srch_booking_window  srch_saturday_night_bool
# count  3049.000000          3049.000000               3049.000000
# mean    112.939023            37.082650                  0.524434
# std     113.374049            46.160272                  0.499485
# min       0.120000             0.000000                  0.000000
# 25%      67.000000             6.000000                  0.000000
# 50%     100.000000            20.000000                  1.000000
# 75%     141.000000            48.000000                  1.000000
# max    5584.000000           292.000000                  1.000000

# %%
df = df.loc[df['price_usd'] < 5584]
df['price_usd'].describe()
# Out:
# count    3048.000000
# mean      111.144055
# std        55.055161
# min         0.120000
# 25%        67.000000
# 50%       100.000000
# 75%       141.000000
# max       536.000000
# Name: price_usd, dtype: float64

# %%
print(df['date_time'].min())
print(df['date_time'].max())
# Out:
# 2012-11-01 02:48:30
# 2013-06-30 22:50:21

# %%
df['date_time'].describe()

df['date_time'] = pd.to_datetime(df['date_time'])

df.head()
# Out:
#                 date_time  price_usd  srch_booking_window  \
# 2041  2013-03-14 11:27:28      206.0                   99
# 3152  2013-01-03 20:48:24      186.0                    6
# 5166  2013-01-19 16:51:27       61.0                    1
# 10135 2013-01-26 11:34:23       72.0                  116
# 10560 2013-04-29 09:39:50      246.0                  245
#
#        srch_saturday_night_bool
# 2041                          1
# 3152                          0
# 5166                          0
# 10135                         0
# 10560                         0

# %%
from matplotlib import cm
cmap = cm.get_cmap('Spectral')
df.plot(x = 'date_time', 
        y = 'price_usd', 
        figsize = (16, 8),cmap=cmap)

plt.xlabel('dates')
plt.ylabel('USD')
plt.title('Time series of room price by date of search');

# %%
a = df.loc[df['srch_saturday_night_bool'] == 0, 'price_usd']
b = df.loc[df['srch_saturday_night_bool'] == 1, 'price_usd']

plt.figure(figsize = (16, 8))

plt.hist(a, bins = 80, 
         alpha = 0.3, 
         label = 'search w/o Sat night stay')

plt.hist(b, bins = 80, 
         alpha = 0.3, 
         label = 'search w/ Sat night stay')

plt.xlabel('Price')
plt.ylabel('Freq')
plt.legend()
plt.title('Sat night search')
plt.plot();

# %%
sns.distplot(df['price_usd'], 
                 hist = False, label = 'USD')

sns.distplot(df['srch_booking_window'], 
                  hist = False, label = 'booking window')

plt.xlabel('dist')
sns.despine()

# %%
sns.pairplot(df)

# %%
df = df.sort_values('date_time')
df['date_time_int'] = df.date_time.astype(np.int64)

# %%
sns.kdeplot(df[["price_usd", "srch_booking_window", "srch_saturday_night_bool"]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
from sklearn.cluster import KMeans
data = df[['price_usd', 'srch_booking_window', 'srch_saturday_night_bool']]
n_cluster = range(1, 20)

kmeans = [KMeans(n_clusters = i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]

# %%
fig, ax = plt.subplots(figsize = (16, 8))
ax.plot(n_cluster, scores, color = 'blue')

plt.xlabel('clusters num')
plt.ylabel('score')
plt.title('Elbow curve for K-Means')
plt.show();
